# %%
import numpy as np
import matplotlib.pyplot as plt
x1=np.linspace(-4,0,1000)
x2=np.linspace(4,0,1000)
#x3=np.linspace(-4,4,2000)
y1=-np.sin(x1)
y2=np.cos(x1-2.1)+0.5
plt.plot(x1,y1)
plt.plot(x2,y2,'r')
